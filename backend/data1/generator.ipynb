# %%
# note: this file exists to minify the large set of glassdoor data, reducing to one highly reviewed example of the job per job title.
# these will be turned into example recomendations.

# as an extension, multiple could be offered.  For now, we just give one example per
# import pandas, np, importer, json
import pandas as pd
import numpy as np

# %%
# import csv from downloads
import csv

# read in csv file "glassdoor_reviews.csv" from ~/Downloads
df = pd.read_csv("~/Downloads/glassdoor_reviews.csv")

# %%
# remove all companies with less than 50 reviews
df_over_50 = df.groupby('firm').filter(lambda x: len(x) > 50)
# add average rating column
df_over_50['average_firm_rating'] = df_over_50.groupby('firm')['overall_rating'].transform('mean')
df_over_50['review_count_by_firm_role'] = df_over_50.groupby(['firm', 'job_title'])['overall_rating'].transform('count')
# remove all job_title is not in ["Anonymous Employee", None]
df_over_50 = df_over_50[df_over_50.job_title != "Anonymous Employee"]
df_over_50 = df_over_50[df_over_50.job_title != " Anonymous Employee"]
df_over_50 = df_over_50[df_over_50.job_title != ""]
df_over_50 = df_over_50[df_over_50.job_title != " "]
# filter all reviews with rating < 4
df_over_50 = df_over_50[df_over_50.overall_rating == 5]
# remove all columns except firm, job_title, review_title, review_body, average_firm_rating
# df_over_50 = df_over_50[['firm', 'job_title', 'review_title', 'review_body', 'average_firm_rating']]
# select one review per job_title, selecting the one with the highest average_firm_rating, highest date_review
df_over_50 = df_over_50.sort_values(['job_title', 'review_count_by_firm_role', 'date_review'], ascending=[True, False, False])
df_over_50 = df_over_50.drop_duplicates(subset=['job_title'], keep='first')

# %%
df_over_50
# Out:
#                            firm date_review  \
# 122964                     CBRE  2009-10-23
# 807143  University-of-Sheffield  2008-09-02
# 774789          Thomson-Reuters  2008-06-13
# 408420               J-P-Morgan  2008-06-11
# 24112                       Aon  2009-01-19
# ...                         ...         ...
# 822237                 Waitrose  2014-05-11
# 726108                      SAP  2020-09-24
# 472032      Kingsley-Healthcare  2021-02-23
# 62551               BNP-Paribas  2015-10-22
# 44185                     Apple  2020-08-06
#
#                                       job_title  \
# 122964                          Administrative
# 807143                           Administrator
# 774789                                 Analyst
# 408420                  Applications Architect
# 24112                       Assistant Director
# ...                                         ...
# 822237   supermarket assistant, delivery driver
# 726108                 supplier account manager
# 472032                            supportworker
# 62551                                 uniteller
# 44185      ​ Senior Customer Support Specialist
#
#                                     current                         location  \
# 122964                      Former Employee                      Atlanta, GA
# 807143                     Current Employee      Sheffield, England, England
# 774789                     Current Employee  São Paulo, São Paulo, São Paulo
# 408420                     Current Employee                     Columbus, OH
# 24112                      Current Employee                              NaN
# ...                                     ...                              ...
# 822237   Former Employee, more than 3 years         London, England, England
# 726108  Current Employee, more than 3 years                        Singapore
# 472032   Current Employee, more than 1 year      Lowestoft, England, England
# 62551     Former Employee, more than 1 year                            Cairo
# 44185    Former Employee, more than 5 years                  New Orleans, LA
#
#         overall_rating  work_life_balance  culture_values  \
# 122964               5                4.0             NaN
# 807143               5                5.0             NaN
# 774789               5                4.0             NaN
# 408420               5                5.0             NaN
# 24112                5                4.0             NaN
# ...                ...                ...             ...
# 822237               5                3.0             5.0
# 726108               5                5.0             5.0
# 472032               5                4.0             5.0
# 62551                5                2.0             5.0
# 44185                5                5.0             5.0
#
#         diversity_inclusion  career_opp  comp_benefits  senior_mgmt recommend  \
# 122964                  NaN         2.0            4.0          4.0         v
# 807143                  NaN         3.0            4.0          5.0         v
# 774789                  NaN         4.0            4.0          5.0         v
# 408420                  NaN         4.0            4.0          3.0         v
# 24112                   NaN         5.0            4.0          5.0         v
# ...                     ...         ...            ...          ...       ...
# 822237                  NaN         5.0            4.0          4.0         v
# 726108                  NaN         5.0            5.0          5.0         v
# 472032                  5.0         5.0            5.0          5.0         v
# 62551                   NaN         4.0            5.0          5.0         v
# 44185                   NaN         5.0            5.0          5.0         v
#
#        ceo_approv outlook                                           headline  \
# 122964          v       o                                         CBRE CARES
# 807143          v       o  Nice place to work, Nice place to Live around,...
# 774789          v       o                           Very Nice place to work.
# 408420          v       o  JPMorgan Chase: Once your in, your nuts if you...
# 24112           v       o                      Aon is a great place to work!
# ...           ...     ...                                                ...
# 822237          v       v                                 Fantastic company!
# 726108          v       v                                 Best Place to Work
# 472032          o       v                                Kingsley experience
# 62551           r       r                                          Uniteller
# 44185           v       v         Apple Inc. is an incredible place to work!
#
#                                                      pros  \
# 122964  The HR team is awesome and very supportive of ...
# 807143  Job security, manageable stress level, benefit...
# 774789  Great work environment and professional oportu...
# 408420  The work/life balance at JPMorgan Chase is exc...
# 24112   There are a lot of opportunities at Aon.  It i...
# ...                                                   ...
# 822237  Lots of great benefits\nPeople are very welcom...
# 726108  Flexibility, Employee Friendly Policies, Innov...
# 472032  During the past year with the difficult times ...
# 62551                Very professional in doing their job
# 44185   They are excited about their products and how ...
#
#                                                      cons  \
# 122964  For administrative personnel, not alot of oppo...
# 807143  Less pay than industry. Recent system implemen...
# 774789         Distance between different working groups.
# 408420  It's a very large company, so there are many b...
# 24112   There seem to be a lot of cliques and people g...
# ...                                                   ...
# 822237  The work is sometimes a little boring\nAs with...
# 726108       Processes could be a little more streamlined
# 472032              There's been some challenging moments
# 62551   You can not balance between your work and your...
# 44185   It's hard to find a con working for Appel, I c...
#
#         average_firm_rating  review_count_by_firm_role
# 122964             3.660349                          1
# 807143             4.370656                          1
# 774789             3.578771                          1
# 408420             3.712443                          3
# 24112              3.475472                          1
# ...                     ...                        ...
# 822237             3.943861                          2
# 726108             4.254532                          2
# 472032             4.500000                          1
# 62551              3.508651                          1
# 44185              4.048420                          1
#
# [28124 rows x 20 columns]

# %%
# match the string to the closest job title in the job title list
# return the full row from df_over_50
def match_job_title(job_title):
    # lookup in the df_over_50 dataframe for the closest job title, using fuzzy matching
    df_over_50_filtered = df_over_50[df_over_50['review_count_by_firm_role'] > 50]
    matching = df_over_50_filtered[df_over_50_filtered['job_title'].str.contains(job_title, case=False)].sort_values('average_firm_rating', ascending=False)
    # if there is no match, return None
    if matching.empty:
        return {
            "firm": "No Match",
            "date_review": "No Match",
            "job_title": "No Match",
            "average_firm_rating": "No Match",
            "overall_rating": "No Match",
            "headline": "No Match",
            "pros": "No Match",
            "cons": "No Match",
        }
    else:
        first = matching.iloc[0]
        return {
            "firm": first['firm'],
            "date_review": first['date_review'],
            "job_title": first['job_title'],
            "average_firm_rating": first['average_firm_rating'],
            "overall_rating": first['overall_rating'],
            "headline": first['headline'],
            "pros": first['pros'],
            "cons": first['cons'],
        }

# %%
match_job_title("engineer")
# Out:
# firm                                                     Google
# date_review                                          2021-06-04
# job_title                                     Software Engineer
# current                                        Current Employee
# location                                                    NaN
# overall_rating                                                5
# work_life_balance                                           4.0
# culture_values                                              4.0
# diversity_inclusion                                         4.0
# career_opp                                                  4.0
# comp_benefits                                               4.0
# senior_mgmt                                                 4.0
# recommend                                                     v
# ceo_approv                                                    v
# outlook                                                       v
# headline                                Good working experience
# pros                         It has a good working environment.
# cons                          there is no obvious cons overall.
# average_firm_rating                                    4.392998
# review_count_by_firm_role                                  2094
# Name: 302118, dtype: object
# {'firm': 'Google',
#  'date_review': '2021-06-04',
#  'job_title': ' Software Engineer',
#  'average_firm_rating': 4.392997811816192,
#  'overall_rating': 5,
#  'headline': 'Good working experience',
#  'pros': 'It has a good working environment.',
#  'cons': 'there is no obvious cons overall.'}

# %%
# export the dataframe to a csv file
df_over_50.to_csv('glassdoor_top_firm_and_review.csv', index=False)

# %%
# import csv from data1/glassdoor_top_firm_and_review.csv

true_df = pd.read_csv("data1/glassdoor_top_firm_and_review.csv")
